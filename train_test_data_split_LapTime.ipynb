# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
from sklearn.preprocessing import StandardScaler
import warnings

# %%
df_recent = pd.read_csv('~/Desktop/Redback/Ultimate_df_recent.csv')
remove_cols = ['Unnamed: 0'] 
df_recent = df_recent.drop(remove_cols, axis=1)

# %%
input_params = df_recent.iloc[:, -33:]

# %%
Speed = df_recent.iloc[:, df_recent.columns == "SpeedKMH_max"]

# %%
train = df_recent.sample(frac = 0.7, random_state = 1)
test = df_recent[df_recent.index.isin(train.index) == False].copy()

# %%
input_params["SpeedKMH_max"] = Speed

# %%
input_params
# Out:
#       brakes_DATA_MAX_TORQUE  brakes_DATA_FRONT_SHARE  \
# 0                  584.97838                  0.68159
# 1                  584.97838                  0.68159
# 2                  584.97838                  0.68159
# 3                  584.97838                  0.68159
# 4                  584.97838                  0.68159
# ...                      ...                      ...
# 1319               551.55454                  0.73680
# 1320               551.55454                  0.73680
# 1321               551.55454                  0.73680
# 1322               551.55454                  0.73680
# 1323               551.55454                  0.73680
#
#       drivetrain_DIFFERENTIAL_POWER  drivetrain_DIFFERENTIAL_COAST  \
# 0                           0.04899                        0.25441
# 1                           0.04899                        0.25441
# 2                           0.04899                        0.25441
# 3                           0.04899                        0.25441
# 4                           0.04899                        0.25441
# ...                             ...                            ...
# 1319                        0.12345                        0.69618
# 1320                        0.12345                        0.69618
# 1321                        0.12345                        0.69618
# 1322                        0.12345                        0.69618
# 1323                        0.12345                        0.69618
#
#       drivetrain_DIFFERENTIAL_PRELOAD  suspensions_BASIC_WHEELBASE  \
# 0                            11.56795                      1.64804
# 1                            11.56795                      1.64804
# 2                            11.56795                      1.64804
# 3                            11.56795                      1.64804
# 4                            11.56795                      1.64804
# ...                               ...                          ...
# 1319                         10.47900                      1.86659
# 1320                         10.47900                      1.86659
# 1321                         10.47900                      1.86659
# 1322                         10.47900                      1.86659
# 1323                         10.47900                      1.86659
#
#       suspensions_BASIC_CG_LOCATION  suspensions_ARB_FRONT  \
# 0                           0.42788           107461.69122
# 1                           0.42788           107461.69122
# 2                           0.42788           107461.69122
# 3                           0.42788           107461.69122
# 4                           0.42788           107461.69122
# ...                             ...                    ...
# 1319                        0.42079            42216.67898
# 1320                        0.42079            42216.67898
# 1321                        0.42079            42216.67898
# 1322                        0.42079            42216.67898
# 1323                        0.42079            42216.67898
#
#       suspensions_ARB_REAR  suspensions_FRONT_TRACK  ...  \
# 0             116229.74284                  1.22661  ...
# 1             116229.74284                  1.22661  ...
# 2             116229.74284                  1.22661  ...
# 3             116229.74284                  1.22661  ...
# 4             116229.74284                  1.22661  ...
# ...                    ...                      ...  ...
# 1319          122339.20205                  1.06626  ...
# 1320          122339.20205                  1.06626  ...
# 1321          122339.20205                  1.06626  ...
# 1322          122339.20205                  1.06626  ...
# 1323          122339.20205                  1.06626  ...
#
#       suspensions_REAR_SPRING_RATE  suspensions_REAR_BUMP_STOP_RATE  \
# 0                      56670.77262                     104990.04453
# 1                      56670.77262                     104990.04453
# 2                      56670.77262                     104990.04453
# 3                      56670.77262                     104990.04453
# 4                      56670.77262                     104990.04453
# ...                            ...                              ...
# 1319                   35590.17408                      78945.44905
# 1320                   35590.17408                      78945.44905
# 1321                   35590.17408                      78945.44905
# 1322                   35590.17408                      78945.44905
# 1323                   35590.17408                      78945.44905
#
#       suspensions_REAR_PACKER_RANGE  suspensions_REAR_DAMP_BUMP  \
# 0                           0.10876                  1198.99360
# 1                           0.10876                  1198.99360
# 2                           0.10876                  1198.99360
# 3                           0.10876                  1198.99360
# 4                           0.10876                  1198.99360
# ...                             ...                         ...
# 1319                        0.06733                  2623.27446
# 1320                        0.06733                  2623.27446
# 1321                        0.06733                  2623.27446
# 1322                        0.06733                  2623.27446
# 1323                        0.06733                  2623.27446
#
#       suspensions_REAR_DAMP_FAST_BUMP  suspensions_REAR_DAMP_REBOUND  \
# 0                           503.80323                     2101.67425
# 1                           503.80323                     2101.67425
# 2                           503.80323                     2101.67425
# 3                           503.80323                     2101.67425
# 4                           503.80323                     2101.67425
# ...                               ...                            ...
# 1319                       3429.20750                     1820.40333
# 1320                       3429.20750                     1820.40333
# 1321                       3429.20750                     1820.40333
# 1322                       3429.20750                     1820.40333
# 1323                       3429.20750                     1820.40333
#
#       suspensions_REAR_DAMP_FAST_REBOUND  tyres_FRONT_PRESSURE_STATIC  \
# 0                             1153.26332                     15.86391
# 1                             1153.26332                     15.86391
# 2                             1153.26332                     15.86391
# 3                             1153.26332                     15.86391
# 4                             1153.26332                     15.86391
# ...                                  ...                          ...
# 1319                          1660.40021                     14.44796
# 1320                          1660.40021                     14.44796
# 1321                          1660.40021                     14.44796
# 1322                          1660.40021                     14.44796
# 1323                          1660.40021                     14.44796
#
#       tyres_REAR_PRESSURE_STATIC  SpeedKMH_max
# 0                       11.37812     84.609711
# 1                       11.37812     90.476089
# 2                       11.37812     90.427589
# 3                       11.37812     90.181877
# 4                       11.37812     89.712265
# ...                          ...           ...
# 1319                    15.89340     86.143707
# 1320                    15.89340     86.206688
# 1321                    15.89340     86.124931
# 1322                    15.89340     86.559700
# 1323                    15.89340     86.405434
#
# [1324 rows x 34 columns]

# %%
response = ['LapTime_max']
predictors = input_params.columns
mu = train[predictors].mean() # mean for each feature
sigma = train[predictors].std() # std for each feature

# %%
mu.head()
# Out:
# brakes_DATA_MAX_TORQUE             611.050241
# brakes_DATA_FRONT_SHARE              0.676043
# drivetrain_DIFFERENTIAL_POWER        0.414661
# drivetrain_DIFFERENTIAL_COAST        0.469073
# drivetrain_DIFFERENTIAL_PRELOAD     12.210391
# dtype: float64

# %%
sigma.head()
# Out:
# brakes_DATA_MAX_TORQUE             112.753669
# brakes_DATA_FRONT_SHARE              0.095848
# drivetrain_DIFFERENTIAL_POWER        0.291044
# drivetrain_DIFFERENTIAL_COAST        0.274821
# drivetrain_DIFFERENTIAL_PRELOAD      6.666559
# dtype: float64

# %%
train[predictors] = (train[predictors] - mu)/sigma
test[predictors] = (test[predictors] - mu)/sigma

# %%
mu = train[predictors].mean() # mean for each feature
sigma = train[predictors].std() # std for each feature

# %%
mu.head()
# Out:
# brakes_DATA_MAX_TORQUE             1.245558e-17
# brakes_DATA_FRONT_SHARE            1.234060e-15
# drivetrain_DIFFERENTIAL_POWER      2.299491e-17
# drivetrain_DIFFERENTIAL_COAST     -1.303045e-16
# drivetrain_DIFFERENTIAL_PRELOAD   -1.053933e-16
# dtype: float64

# %%
sigma.head()
# Out:
# brakes_DATA_MAX_TORQUE             1.0
# brakes_DATA_FRONT_SHARE            1.0
# drivetrain_DIFFERENTIAL_POWER      1.0
# drivetrain_DIFFERENTIAL_COAST      1.0
# drivetrain_DIFFERENTIAL_PRELOAD    1.0
# dtype: float64

# %%
y_train = train.iloc[:, train.columns == "LapTime_max"]
X_train = train[predictors]
y_test = test.iloc[:, test.columns == "LapTime_max"]
X_test = test[predictors]

# %%
train = y_train.join(X_train)
test = y_test.join(X_test)

# %%
test
# Out:
#       LapTime_max  brakes_DATA_MAX_TORQUE  brakes_DATA_FRONT_SHARE  \
# 15          41301               -0.947408                -0.186581
# 20          41202               -0.947408                -0.186581
# 21          41136               -0.947408                -0.186581
# 24          42048               -0.459390                 1.286896
# 25          41922               -0.459390                 1.286896
# ...           ...                     ...                      ...
# 1312        42156               -0.527661                 0.633884
# 1319        42354               -0.527661                 0.633884
# 1320        42117               -0.527661                 0.633884
# 1322        42282               -0.527661                 0.633884
# 1323        41868               -0.527661                 0.633884
#
#       drivetrain_DIFFERENTIAL_POWER  drivetrain_DIFFERENTIAL_COAST  \
# 15                        -0.987344                      -1.492070
# 20                        -0.987344                      -1.492070
# 21                        -0.987344                      -1.492070
# 24                        -0.649045                       0.364408
# 25                        -0.649045                       0.364408
# ...                             ...                            ...
# 1312                      -1.000572                       0.826381
# 1319                      -1.000572                       0.826381
# 1320                      -1.000572                       0.826381
# 1322                      -1.000572                       0.826381
# 1323                      -1.000572                       0.826381
#
#       drivetrain_DIFFERENTIAL_PRELOAD  suspensions_BASIC_WHEELBASE  \
# 15                           0.862829                     0.987832
# 20                           0.862829                     0.987832
# 21                           0.862829                     0.987832
# 24                           0.701657                     0.306738
# 25                           0.701657                     0.306738
# ...                               ...                          ...
# 1312                        -0.259713                     1.698538
# 1319                        -0.259713                     1.698538
# 1320                        -0.259713                     1.698538
# 1322                        -0.259713                     1.698538
# 1323                        -0.259713                     1.698538
#
#       suspensions_BASIC_CG_LOCATION  suspensions_ARB_FRONT  \
# 15                         1.808506               1.598770
# 20                         1.808506               1.598770
# 21                         1.808506               1.598770
# 24                         0.594878              -1.763979
# 25                         0.594878              -1.763979
# ...                             ...                    ...
# 1312                      -0.764420              -0.964367
# 1319                      -0.764420              -0.964367
# 1320                      -0.764420              -0.964367
# 1322                      -0.764420              -0.964367
# 1323                      -0.764420              -0.964367
#
#       suspensions_ARB_REAR  ...  suspensions_REAR_SPRING_RATE  \
# 15               -0.989155  ...                     -0.436838
# 20               -0.989155  ...                     -0.436838
# 21               -0.989155  ...                     -0.436838
# 24                0.233039  ...                      1.219924
# 25                0.233039  ...                      1.219924
# ...                    ...  ...                           ...
# 1312              0.886356  ...                     -0.751698
# 1319              0.886356  ...                     -0.751698
# 1320              0.886356  ...                     -0.751698
# 1322              0.886356  ...                     -0.751698
# 1323              0.886356  ...                     -0.751698
#
#       suspensions_REAR_BUMP_STOP_RATE  suspensions_REAR_PACKER_RANGE  \
# 15                          -0.842743                      -0.243007
# 20                          -0.842743                      -0.243007
# 21                          -0.842743                      -0.243007
# 24                          -1.185068                      -0.953711
# 25                          -1.185068                      -0.953711
# ...                               ...                            ...
# 1312                        -0.995565                      -0.677469
# 1319                        -0.995565                      -0.677469
# 1320                        -0.995565                      -0.677469
# 1322                        -0.995565                      -0.677469
# 1323                        -0.995565                      -0.677469
#
#       suspensions_REAR_DAMP_BUMP  suspensions_REAR_DAMP_FAST_BUMP  \
# 15                      0.456334                         1.484082
# 20                      0.456334                         1.484082
# 21                      0.456334                         1.484082
# 24                      0.627447                         1.089141
# 25                      0.627447                         1.089141
# ...                          ...                              ...
# 1312                    0.007018                         1.443360
# 1319                    0.007018                         1.443360
# 1320                    0.007018                         1.443360
# 1322                    0.007018                         1.443360
# 1323                    0.007018                         1.443360
#
#       suspensions_REAR_DAMP_REBOUND  suspensions_REAR_DAMP_FAST_REBOUND  \
# 15                        -1.404045                            0.728789
# 20                        -1.404045                            0.728789
# 21                        -1.404045                            0.728789
# 24                        -0.158915                            0.339060
# 25                        -0.158915                            0.339060
# ...                             ...                                 ...
# 1312                      -1.284856                           -0.510023
# 1319                      -1.284856                           -0.510023
# 1320                      -1.284856                           -0.510023
# 1322                      -1.284856                           -0.510023
# 1323                      -1.284856                           -0.510023
#
#       tyres_FRONT_PRESSURE_STATIC  tyres_REAR_PRESSURE_STATIC  SpeedKMH_max
# 15                       1.636737                   -0.200990      0.307481
# 20                       1.636737                   -0.200990      0.312627
# 21                       1.636737                   -0.200990      0.303285
# 24                       1.223062                    0.435088     -0.033375
# 25                       1.223062                    0.435088      0.000796
# ...                           ...                         ...           ...
# 1312                     0.502647                    0.734029     -0.192657
# 1319                     0.502647                    0.734029     -0.263067
# 1320                     0.502647                    0.734029     -0.250439
# 1322                     0.502647                    0.734029     -0.179659
# 1323                     0.502647                    0.734029     -0.210590
#
# [397 rows x 35 columns]

# %%
train
# Out:
#       LapTime_max  brakes_DATA_MAX_TORQUE  brakes_DATA_FRONT_SHARE  \
# 1160        43914                1.513706                -0.496028
# 571         41256                0.440057                 1.564940
# 65          40647                1.250806                 0.863518
# 115         39945               -1.830338                 0.096889
# 1253        40476               -1.616643                 1.317361
# ...           ...                     ...                      ...
# 260         40752               -1.253020                -0.787218
# 1128        41544                1.592009                -0.186163
# 333         41787                0.102421                 0.694292
# 153         46311                1.094944                -1.777535
# 396         40668               -0.649310                -1.212892
#
#       drivetrain_DIFFERENTIAL_POWER  drivetrain_DIFFERENTIAL_COAST  \
# 1160                       0.749747                      -0.574274
# 571                       -0.589535                       0.314667
# 65                        -0.374172                       1.551179
# 115                       -0.169427                      -1.246456
# 1253                       1.204248                       1.282240
# ...                             ...                            ...
# 260                        0.917728                       0.787556
# 1128                      -1.186386                       0.152926
# 333                       -0.802115                      -0.297512
# 153                       -0.953535                       0.946532
# 396                        0.698380                       0.588335
#
#       drivetrain_DIFFERENTIAL_PRELOAD  suspensions_BASIC_WHEELBASE  \
# 1160                         0.945005                     0.443342
# 571                         -0.189615                     1.628311
# 65                          -0.634678                    -1.173899
# 115                          1.638991                    -0.223908
# 1253                         1.104064                    -1.093954
# ...                               ...                          ...
# 260                         -1.069729                     1.388933
# 1128                         0.913135                    -1.241835
# 333                         -0.140659                     0.586363
# 153                          1.265623                     0.679602
# 396                          0.919420                    -0.251962
#
#       suspensions_BASIC_CG_LOCATION  suspensions_ARB_FRONT  \
# 1160                      -0.995821              -1.910269
# 571                        0.317802               0.931124
# 65                        -1.213966              -0.403501
# 115                        1.382735              -0.645199
# 1253                      -0.402191               0.170541
# ...                             ...                    ...
# 260                        1.446852              -1.307422
# 1128                      -0.814562              -1.027952
# 333                       -0.215168              -0.543295
# 153                       -0.800586               0.443622
# 396                        0.849476               1.192994
#
#       suspensions_ARB_REAR  ...  suspensions_REAR_SPRING_RATE  \
# 1160             -1.457874  ...                      0.322634
# 571               1.298159  ...                      0.854476
# 65                0.423389  ...                     -0.286708
# 115               0.370391  ...                     -0.607310
# 1253              0.035663  ...                      1.374368
# ...                    ...  ...                           ...
# 260              -0.208520  ...                      1.061962
# 1128              1.394277  ...                     -0.812524
# 333               1.241881  ...                      1.450289
# 153              -0.393545  ...                      0.138978
# 396               0.120137  ...                     -1.397349
#
#       suspensions_REAR_BUMP_STOP_RATE  suspensions_REAR_PACKER_RANGE  \
# 1160                         1.654680                      -1.664843
# 571                          0.118775                       0.265861
# 65                          -1.196300                       1.468756
# 115                         -1.353579                      -0.435863
# 1253                         0.426107                       1.099293
# ...                               ...                            ...
# 260                          1.419798                       0.896601
# 1128                        -0.022052                       1.212184
# 333                          0.458616                      -0.729638
# 153                          0.457529                       0.083267
# 396                         -1.036409                      -0.249421
#
#       suspensions_REAR_DAMP_BUMP  suspensions_REAR_DAMP_FAST_BUMP  \
# 1160                   -1.170158                        -1.054219
# 571                    -1.541565                         1.354502
# 65                     -1.107191                        -1.273721
# 115                     1.464349                         1.375929
# 1253                    1.109631                         1.476217
# ...                          ...                              ...
# 260                    -1.378914                         0.345468
# 1128                   -0.158866                        -1.354222
# 333                    -0.395471                        -1.445544
# 153                     0.350781                         1.165338
# 396                    -1.557249                        -0.903989
#
#       suspensions_REAR_DAMP_REBOUND  suspensions_REAR_DAMP_FAST_REBOUND  \
# 1160                       1.388344                           -0.019542
# 571                        0.884019                            1.675101
# 65                         1.703593                            1.290507
# 115                       -1.157524                            0.205979
# 1253                       0.307232                            0.905936
# ...                             ...                                 ...
# 260                        0.148040                            1.631341
# 1128                       0.624633                            0.749008
# 333                       -1.287025                            0.191599
# 153                        0.589153                           -1.677578
# 396                       -1.264318                           -1.810257
#
#       tyres_FRONT_PRESSURE_STATIC  tyres_REAR_PRESSURE_STATIC  SpeedKMH_max
# 1160                     0.373114                   -1.278439     -1.403021
# 571                     -0.908377                    0.292293      0.854514
# 65                       0.883771                    1.840896      1.053696
# 115                     -0.686924                    1.726430      1.010909
# 1253                     1.401298                   -0.505198      0.438215
# ...                           ...                         ...           ...
# 260                     -1.102068                    1.026490      0.799436
# 1128                    -0.908747                    0.415245      0.593297
# 333                     -1.256889                    1.764098     -0.560473
# 153                      1.209412                   -1.430639     -2.548931
# 396                      1.547263                    0.908235      0.613019
#
# [927 rows x 35 columns]

# %%
train.to_csv('train_incl_speed.csv')
test.to_csv('test_incl_speed.csv')
